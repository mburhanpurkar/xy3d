# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
J01K01 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.1_K0.1.txt'))
np.shape(J01K01)
# Out:
# (2, 5000)

# %%
plt.plot(J01K01[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()

# %%
plt.plot(J01K01[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J01K2 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.1_K2.0.txt'))
np.shape(J01K2)
# Out:
# (2, 5000)

# %%
plt.plot(J01K2[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()

# %%
plt.plot(J01K2[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J01K1 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.1_K1.0.txt'))
np.shape(J01K1)
plt.plot(J01K1[0], "ro")
plt.ylabel("Winding")
plt.show()
plt.plot(J01K1[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J01K15 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.1_K1.5.txt'))
np.shape(J01K15)
plt.plot(J01K15[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()
plt.plot(J01K15[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J01K12 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.1_K1.2.txt'))
np.shape(J01K12)
plt.plot(J01K12[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()
plt.plot(J01K12[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J04K1 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.4_K1.0.txt'))
np.shape(J04K1)
plt.plot(J04K1[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()
plt.plot(J04K1[1], "bo")
plt.ylabel("Magnetization")
plt.show()

# %%
J001K1 = np.transpose(np.loadtxt('time_series_full_xy3d_n30_J0.01_K1.0.txt'))
np.shape(J001K1)
plt.plot(J001K1[0] * 30, "ro")
plt.ylabel("Winding")
plt.show()
plt.plot(J001K1[1], "bo")
plt.ylabel("Magnetization")
plt.show()
